# %% [markdown]
# # Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# # Read the Dataset

# %%
df = pd.read_csv("Titanic_Dataset.csv")

# %% [markdown]
# # Explore the Dataset

# %%
df.head(10) #Gives first 5 rows of the dataset by default
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %% [markdown]
# # Last Rows

# %%
df.tail() # Returns last 5 elements as default
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # Data Size

# %%
df.shape       # Rows and Columns
# Out:
# (418, 12)

# %% [markdown]
# # Column Names

# %%
df.columns # Returns column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# # Data Types

# %%
df.dtypes # Provides data type of each column in the table
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# # To get complete Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %% [markdown]
# # For statsical summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()  # Gives the missing value
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()   #Count missing value
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.duplicated() # For getting duplicate rows
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.drop_duplicates()  # Remove duplicate rows from the data frame
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Selecting Data

# %%
df["Age"] # Selecting single column
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df[["Age","Name"]]      # Selecting two columns
# Out:
#       Age                                          Name
# 0    34.5                              Kelly, Mr. James
# 1    47.0              Wilkes, Mrs. James (Ellen Needs)
# 2    62.0                     Myles, Mr. Thomas Francis
# 3    27.0                              Wirz, Mr. Albert
# 4    22.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...                                           ...
# 413   NaN                            Spector, Mr. Woolf
# 414  39.0                  Oliva y Ocana, Dona. Fermina
# 415  38.5                  Saether, Mr. Simon Sivertsen
# 416   NaN                           Ware, Mr. Frederick
# 417   NaN                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %% [markdown]
# # Row Selection

# %%
df.iloc[0]  # always fetches the absolute first row of the DataFrame based on its physical integer position (0-indexed)
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.loc[0] # looks for the explicit row label named 0
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %% [markdown]
# # Filtering of the Data

# %%
df[df["Age"]>60]    # On single condition
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 13           905         0       2
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 142         1034         0       1
# 152         1044         0       3
# 179         1071         1       1
# 193         1085         0       2
# 236         1128         0       1
# 305         1197         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ...

# %%
df[(df["Age"]>50) & (df["Sex"] == "male")] # On multiple condition
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 2            894         0       2        Myles, Mr. Thomas Francis  male
# 13           905         0       2             Howard, Mr. Benjamin  male
# 20           912         0       1           Rothschild, Mr. Martin  male
# 81           973         0       1               Straus, Mr. Isidor  male
# 131         1023         0       1        Gracie, Col. Archibald IV  male
# 142         1034         0       1       Ryerson, Mr. Arthur Larned  male
# 152         1044         0       3               Storey, Mr. Thomas  male
# 177         1069         0       1  Stengel, Mr. Charles Emil Henry  male
# 193         1085         0       2                Lingane, Mr. John  male
# 217         1109         0       1         Wick, Mr. George Dennick  male
# 236         1128         0       1         Warren, Mr. Frank Manley  male
# 293         1185         0       1            Dodge, Dr. Washington  male
# ...

# %% [markdown]
# # Sorting Data

# %%
df.sort_values("Age")   # Series Method -> Where we use one col
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...
